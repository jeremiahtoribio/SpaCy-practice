# %%
import spacy
import en_core_web_sm
from goose3 import Goose
from spacy import displacy
import nltk
import string
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
nlp_pt = spacy.load("pt_core_news_sm")

# %%
nlp_pt

# %%
g = Goose()
url_pt_ex = 'https://expresso.pt/internacional/isabel-ii/2022-09-14-Carlos-III-criticado-apos-noticia-de-despedimentos-de-funcionarios-b4ac0873'
article_pt = g.extract(url_pt_ex)

# %%
dataset = nlp_pt(article_pt.cleaned_text)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/jer/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
displacy.render(dataset, style = 'ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A notícia de que até 100 funcionários da antiga residência do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rei Carlos III
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  poderão perder os seus empregos está a suscitar críticas à monarquia britânica, poucos dias após a proclamação do filho primogénito da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rainha Isabel II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . O jornal britânico “
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Guardian”
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  noticiou na terça-feira que dezenas de funcionários da
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clarence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  House, antiga residência oficial de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carlos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , foram avisados de que os seus empregos estavam em risco.</br></br>A reportagem dizia que os avisos chegaram no meio de um período de transição atarefado, quando
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carlos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  e a esposa Camilla, a rainha consorte, se mudaram para o
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Palácio de Buckingham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  após a morte da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rainha Isabel II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , na passada quinta-feira.</br></br>O
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sindicato dos Serviços Públicos e Comerciais
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  apelidou a decisão de informar o pessoal sobre cortes de postos de trabalho durante um período de luto &quot;nada menos do que insensível&quot;. &quot;Embora fosse de esperar algumas mudanças nas equipas, pois os papéis em toda a família real vão mudar, a escala e a velocidade a que isto foi anunciado é extremamente insensível&quot;, lamentou o secretário-geral do sindicato,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Serwotka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br></br>O
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reino Unido
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  encontra-se num período nacional de luto até segunda-feira, quando o funeral de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Estado da Rainha
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  será realizado.</br></br>Num comunicado, a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clarence House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  explicou que, após a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     proclamação do Rei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , as operações das equipas de apoio a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carlos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  e de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Camilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  &quot;cessaram&quot; e &quot;como exigido por lei, foi iniciado um processo de consulta&quot;.</br></br>&quot;O nosso pessoal prestou um serviço longo e leal e, embora alguns despedimentos sejam inevitáveis, estamos a trabalhar urgentemente para identificar papéis alternativos para o maior número possível de funcionários&quot;, acrescentou a declaração.</br></br>&quot;Todos estão absolutamente lívidos (...) as pessoas ficaram visivelmente abaladas com isto&quot;, disse, por sua vez, um funcionário de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carlos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , que falou ao jornal
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Guardian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sob a condição de anonimato.</br></br>Também nos últimos dias foram divulgados dois vídeos que estão a gerar polémica e que vieram contribuir para reforçar a imagem negativa do monarca de 73 anos. Os vídeos em questão, que o mostram visivelmente irritado com uma caneta que largava tinta e um tinteiro, foram amplamente partilhados nas redes sociais.</br></br>Num vídeo, vê-se o
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  a perder a calma com uma

# %%
tokens = nltk.tokenize.word_tokenize(article_pt.cleaned_text)

# %%
cloud = WordCloud()
cloud = cloud.generate(article_pt.cleaned_text)
plt.figure(figsize=(15,15))
plt.imshow(cloud)
plt.axis('off');
